# %% [markdown]
# # 統計力学の授業でやったやつ

# %% [markdown]
# ## stirlingの公式
# 統計力学でよく出てくるのは
# $$\log (n!) \propto n(\log n  - 1) $$
# のかたち．

# %%
using Plots

N = 20
n = 0:N

approx = n .* (log.(n).-1)

exact = []
for i ∈ n
    f = log(factorial(i))
    append!(exact, f)
end

plot(n, approx, label="approx")
plot!(n, exact, label="exact")

# %% [markdown]
# もう少しちゃんと書くと，
# $$(n!\sim)\ \Gamma(x+1)=\sqrt{2\pi n}(n/e)^n$$

# %%
using Plots
using SpecialFunctions

x = 0:0.1:3.5
exact = gamma.(x.+1)

approx = sqrt.(2 .* π .* x) .* (x ./ ℯ).^x

plot(x, exact, label="exact")
plot!(x, approx, label="approx")

# %% [markdown]
# ## 各粒子が1/2の確率でどちらかに存在し，$N$粒子中$n$粒子が片方に存在する確率
#
# 授業でやってたやつ．
# $$
#     \log P
#     =\log \left(\frac{N!}{(N-n)!n!}(1/2)^{N} \right)
#     \sim-N \left(\log 2 + \frac{n}{N}\log\frac{n}{N}+\frac{N-n}{N}\log\frac{N-n}{N}\right)
# $$

# %%
using Plots

N = 20
n = 1:N-1

P = -N .* (log(2) .+ n./N .* log.(n./N) .+ (N.-n) ./N .* log.( (N.-n)./N))

norm = sum(ℯ.^P)
plot(n, ℯ.^P/norm)

exact = []
for i ∈ n
    pn = factorial(N)/(factorial(N-i) * factorial(i)) * 0.5^N
    append!(exact, pn)
end

println(exact)
plot!(n, exact, label="exact")
# Out:
# Any[1.9073486328125e-5, 0.0001811981201171875, 0.001087188720703125, 0.004620552062988281, 0.0147857666015625, 0.03696441650390625, 0.0739288330078125, 0.12013435363769531, 0.16017913818359375, 0.17619705200195312, 0.16017913818359375, 0.12013435363769531, 0.0739288330078125, 0.03696441650390625, 0.0147857666015625, 0.004620552062988281, 0.001087188720703125, 0.0001811981201171875, 1.9073486328125e-5]

# %% [markdown]
# $x = n/N -1/2$でみやすく．

# %%
using Plots

N = 20
x = 1:N
prob = ℯ.^(-N .* (log.(2) .+ (x.+1/2) .* log.(x .+ 1/2) .+ (1/2 .- x) .* log.(1/2 .-x)))

plot(x, prob)
# Out:
# DomainError with -0.5:
# log will only return a complex result if called with a complex argument. Try log(Complex(x)).
#
# Stacktrace:
#   [1] throw_complex_domainerror(f::Symbol, x::Float64)
#     @ Base.Math ./math.jl:33
#   [2] log(x::Float64)
#     @ Base.Math ./special/log.jl:285
#   [3] _broadcast_getindex_evalf
#     @ ./broadcast.jl:648 [inlined]
#   [4] _broadcast_getindex
#     @ ./broadcast.jl:621 [inlined]
#   [5] _getindex
#     @ ./broadcast.jl:645 [inlined]
#   [6] _getindex
#     @ ./broadcast.jl:644 [inlined]
#   [7] _broadcast_getindex
#     @ ./broadcast.jl:620 [inlined]
#   [8] _getindex
#     @ ./broadcast.jl:645 [inlined]
#   [9] _getindex
#     @ ./broadcast.jl:644 [inlined]
#  [10] _broadcast_getindex
#     @ ./broadcast.jl:620 [inlined]
#  [11] _getindex
#     @ ./broadcast.jl:645 [inlined]
#  [12] _getindex
#     @ ./broadcast.jl:644 [inlined]
#  [13] _broadcast_getindex
#     @ ./broadcast.jl:620 [inlined]
#  [14] _getindex
#     @ ./broadcast.jl:645 [inlined]
#  [15] _getindex
#     @ ./broadcast.jl:644 [inlined]
#  [16] _broadcast_getindex
#     @ ./broadcast.jl:620 [inlined]
#  [17] getindex
#     @ ./broadcast.jl:575 [inlined]
#  [18] macro expansion
#     @ ./broadcast.jl:984 [inlined]
#  [19] macro expansion
#     @ ./simdloop.jl:77 [inlined]
#  [20] copyto!
#     @ ./broadcast.jl:983 [inlined]
#  [21] copyto!
#     @ ./broadcast.jl:936 [inlined]
#  [22] copy
#     @ ./broadcast.jl:908 [inlined]
#  [23] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(^), Tuple{Irrational{:ℯ}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(*), Tuple{Int64, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(+), Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(+), Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{0}, Nothing, typeof(log), Tuple{Int64}}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(*), Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(log), Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}}}}}}}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(*), Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(log), Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}}}}}}}}}}})
#     @ Base.Broadcast ./broadcast.jl:883
#  [24] top-level scope
#     @ In[12]:5
#  [25] eval
#     @ ./boot.jl:360 [inlined]
#  [26] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116
